# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'agents.yaml',
    'tasks': 'tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Overview
# **Project Goal:** Create a responsive and modern website for a small business that effectively showcases the business's offerings, communicates its values, and engages users.
#
# ### Task Breakdown
#
# 1. **Define Project Requirements**
#    - **Description:** Initiate a meeting with stakeholders to gather and document specific website requirements.
#    - **Scope:** Collect feedback on desired features, branding elements, and benchmark websites.
#    - **Timeline:** 1 week (Days 1-7)
#    - **Dependencies:** None
#    - **Deliverables:** Project requirements document
#
# 2. **Create Responsive Design**
#    - **Description:** Develop a wireframe and design layout that adapts to both desktop and mobile devices.
#    - **Scope:** Ensure design flexibility with common screen resolutions in mind.
#    - **Timeline:** 2 weeks (Days 8-21)
#    - **Dependencies:** Project requirements document
#    - **Deliverables:** Wireframe and responsive design mockups (Figma/Adobe XD)
#
# 3. **Develop User Interface**
#    - **Description:** Convert wireframe into a visually appealing UI using branding guidelines.
#    - **Scope:** Implement color schemes, fonts, and other styling elements.
#    - **Timeline:** 2 weeks (Days 22-35)
#    - **Dependencies:** Responsive design mockups
#    - **Deliverables:** Final UI design
#
# 4. **Create Navigation System**
#    - **Description:** Design and implement the site navigation structure with intuitive menu options.
#    - **Scope:** Ensure easy access to all website pages from anywhere on the site.
#    - **Timeline:** 1 week (Days 36-42)
#    - **Dependencies:** User interface design
#    - **Deliverables:** Functional navigation menu
#
# 5. **Develop "About Us" Page**
#    - **Description:** Create a page that articulates the business's history and values.
#    - **Scope:** Include images and engaging content to tell the company's story.
#    - **Timeline:** 1 week (Days 43-49)
#    - **Dependencies:** None
#    - **Deliverables:** Completed "About Us" page
#
# 6. **Design "Services" Page**
#    - **Description:** Develop a page showcasing offered services with detailed descriptions and images.
#    - **Scope:** Create a list format with engaging elements and CTAs.
#    - **Timeline:** 1 week (Days 50-56)
#    - **Dependencies:** None
#    - **Deliverables:** Completed "Services" page
#
# 7. **Create "Contact Us" Page**
#    - **Description:** Implement a page that includes a contact form and an integrated map.
#    - **Scope:** Ensure GDPR compliance and user-friendly design.
#    - **Timeline:** 1 week (Days 57-63)
#    - **Dependencies:** None
#    - **Deliverables:** Completed "Contact Us" page
#
# 8. **Implement Blog Section**
#    - **Description:** Design and develop a blog section for posting updates and industry news.
#    - **Scope:** Include the ability for team members to create posts easily.
#    - **Timeline:** 2 weeks (Days 64-77)
#    - **Dependencies:** None
#    - **Deliverables:** Functional blog section
#
# 9. **Website Optimization for SEO & Loading Speed**
#    - **Description:** Ensure the overall website is optimized for search engines and fast loading.
#    - **Scope:** Implement SEO best practices and performance tests.
#    - **Timeline:** 1 week (Days 78-84)
#    - **Dependencies:** All website pages
#    - **Deliverables:** SEO and performance analysis report
#
# 10. **Integrate Social Media Links**
#     - **Description:** Embed social media icons and sharing options on appropriate pages.
#     - **Scope:** Ensure all links are functional and lead to the correct platforms.
#     - **Timeline:** 1 week (Days 85-91)
#     - **Dependencies:** None
#     - **Deliverables:** Completed social media integration
#
# 11. **Design Testimonials Section**
#     - **Description:** Create a section to display customer testimonials and feedback.
#     - **Scope:** Collect testimonials and present them in an engaging format.
#     - **Timeline:** 1 week (Days 92-98)
#     - **Dependencies:** None
#     - **Deliverables:** Completed testimonials section
#
# 12. **Quality Assurance Testing**
#     - **Description:** Conduct thorough testing of all functionality, design elements, and performance.
#     - **Scope:** Utilize both QA engineers for comprehensive testing.
#     - **Timeline:** 2 weeks (Days 99-112)
#     - **Dependencies:** Completion of all website pages
#     - **Deliverables:** QA report with identified issues and resolutions
#
# 13. **Launch Website**
#     - **Description:** Deploy the completed website to the selected hosting platform.
#     - **Scope:** Ensure all final checks are conducted and the site is operational.
#     - **Timeline:** 1 week (Days 113-119)
#     - **Dependencies:** Successful QA Testing
#     - **Deliverables:** Live website
#
# ### Gantt Chart Visualization
#
# ```plaintext
# | Task                                       | Duration      | Timeline     |
# |--------------------------------------------|---------------|--------------|
# | Define Project Requirements                 | 1 Week       | Days 1-7     |
# | Create Responsive Design                    | 2 Weeks      | Days 8-21    |
# | Develop User Interface                      | 2 Weeks      | Days 22-35   |
# | Create Navigation System                    | 1 Week       | Days 36-42   |
# | Develop "About Us" Page                    | 1 Week       | Days 43-49   |
# | Design "Services" Page                     | 1 Week       | Days 50-56   |
# | Create "Contact Us" Page                   | 1 Week       | Days 57-63   |
# | Implement Blog Section                      | 2 Weeks      | Days 64-77   |
# | Website Optimization for SEO & Loading Speed| 1 Week      | Days 78-84   |
# | Integrate Social Media Links                | 1 Week       | Days 85-91   |
# | Design Testimonials Section                 | 1 Week       | Days 92-98   |
# | Quality Assurance Testing                   | 2 Weeks      | Days 99-112  |
# | Launch Website                              | 1 Week       | Days 113-119 |
# ```
#
# ### Conclusion
# By following this detailed breakdown with specific timelines and dependencies, the project team can effectively manage the website project for the small business, ensuring high-quality output, timely delivery, and a successful launch. Each team member has clear roles and deliverables within the project scope.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### Task 1: Define Project Requirements
# - **Time Required:** 1 week
# - **Effort:** 20 hours (8 hours for meetings and communications, 12 hours for documentation)
# - **Resources Needed:**
#   - 1 Project Manager
#   - 1 Business Analyst
# - **Risks/Uncertainties:** Limited stakeholder availability could delay requirements gathering. Clear communication channels must be established.
#
# #### Task 2: Create Responsive Design
# - **Time Required:** 2 weeks
# - **Effort:** 40 hours (20 hours for wireframe creation, 20 hours for mockup design)
# - **Resources Needed:**
#   - 1 UI/UX Designer
# - **Risks/Uncertainties:** Misinterpretation of requirements or delayed feedback may extend design iterations.
#
# #### Task 3: Develop User Interface
# - **Time Required:** 2 weeks
# - **Effort:** 40 hours (20 hours for implementation, 20 hours for revisions)
# - **Resources Needed:**
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Compatibility issues with various browsers or devices could arise, requiring additional debugging time.
#
# #### Task 4: Create Navigation System
# - **Time Required:** 1 week
# - **Effort:** 15 hours
# - **Resources Needed:**
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** User testing may reveal navigation issues that need addressing, extending development time.
#
# #### Task 5: Develop "About Us" Page
# - **Time Required:** 1 week
# - **Effort:** 15 hours
# - **Resources Needed:**
#   - 1 Content Writer
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Content not being ready on time could stall development.
#
# #### Task 6: Design "Services" Page
# - **Time Required:** 1 week
# - **Effort:** 15 hours
# - **Resources Needed:**
#   - 1 Content Writer
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Lack of clarity on service descriptions may lead to rework.
#
# #### Task 7: Create "Contact Us" Page
# - **Time Required:** 1 week
# - **Effort:** 15 hours
# - **Resources Needed:**
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Potential challenges with GDPR compliance could introduce delays in site launch.
#
# #### Task 8: Implement Blog Section
# - **Time Required:** 2 weeks
# - **Effort:** 40 hours
# - **Resources Needed:**
#   - 1 Back-End Developer
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Technical limitations on the blog functionality may require system adjustments.
#
# #### Task 9: Website Optimization for SEO & Loading Speed
# - **Time Required:** 1 week
# - **Effort:** 20 hours
# - **Resources Needed:**
#   - 1 SEO Specialist
#   - 1 Developer
# - **Risks/Uncertainties:** Changes in search engine algorithms could limit effectiveness, necessitating ongoing adjustments post-launch.
#
# #### Task 10: Integrate Social Media Links
# - **Time Required:** 1 week
# - **Effort:** 10 hours
# - **Resources Needed:**
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Configuration issues with social platform APIs could delay integration.
#
# #### Task 11: Design Testimonials Section
# - **Time Required:** 1 week
# - **Effort:** 15 hours
# - **Resources Needed:**
#   - 1 UI/UX Designer
#   - 1 Front-End Developer
# - **Risks/Uncertainties:** Delay in collecting testimonials could impact design.
#
# #### Task 12: Quality Assurance Testing
# - **Time Required:** 2 weeks
# - **Effort:** 40 hours
# - **Resources Needed:**
#   - 2 QA Engineers
# - **Risks/Uncertainties:** The complexity of issues found may lead to prolonged testing and fixing phases, delaying the project timeline.
#
# #### Task 13: Launch Website
# - **Time Required:** 1 week
# - **Effort:** 10 hours
# - **Resources Needed:**
#   - 1 Project Manager
#   - 1 Developer
# - **Risks/Uncertainties:** Potential issues during deployment could require rollback or further troubleshooting.
#
# ### Summary of Risks
# 1. **Stakeholder Availability:** Delays in feedback could push the project timeline back.
# 2. **Content Readiness:** Delays in gathering content for development could halt progress.
# 3. **Technical Dependencies:** Relying on third-party tools (e.g., APIs for social media) can pose risks to meeting the timeline.
# 4. **Testing Complexity:** Findings during QA could extend timelines and resource allocation.
#
# ### Conclusion
# The above estimates provide a comprehensive view of the time, effort, and resources required for each task in the Website project. The total project span is 119 days, including buffer periods for any potential risks. Effective project management, proactive communication, and immediate risk mitigation strategies will ensure the project is delivered efficiently and within budget.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                   | Assigned Team Member(s)  | Start Date  | End Date    |
# |----------------------------------------|--------------------------|-------------|-------------|
# | 1. Define Project Requirements         | John Doe                 | 01-Nov-2023 | 07-Nov-2023 |
# | 2. Create Responsive Design            | Bob Smith                | 08-Nov-2023 | 21-Nov-2023 |
# | 3. Develop User Interface              | Jane Doe                 | 22-Nov-2023 | 05-Dec-2023 |
# | 4. Create Navigation System            | Jane Doe                 | 06-Dec-2023 | 12-Dec-2023 |
# | 5. Develop "About Us" Page            | Jane Doe, Bob Smith      | 13-Dec-2023 | 19-Dec-2023 |
# | 6. Design "Services" Page             | Bob Smith                | 20-Dec-2023 | 26-Dec-2023 |
# | 7. Create "Contact Us" Page           | Jane Doe                 | 27-Dec-2023 | 02-Jan-2024 |
# | 8. Implement Blog Section              | Jane Doe, Bob Smith      | 03-Jan-2024 | 16-Jan-2024 |
# | 9. Website Optimization for SEO        | Jane Doe                 | 17-Jan-2024 | 23-Jan-2024 |
# | 10. Integrate Social Media Links       | Jane Doe                 | 24-Jan-2024 | 30-Jan-2024 |
# | 11. Design Testimonials Section        | Bob Smith                | 31-Jan-2024 | 06-Feb-2024 |
# | 12. Quality Assurance Testing          | Alice Johnson, Tom Brown  | 07-Feb-2024 | 20-Feb-2024 |
# | 13. Launch Website                     | John Doe, Jane Doe       | 21-Feb-2024 | 24-Feb-2024 |
#
# ### Allocation Rationale Summary
#
# 1. **Define Project Requirements**: John Doe, as Project Manager, is tasked to lead the requirements phase ensuring efficient stakeholder communication due to his managerial role and expertise in documentation.
#
# 2. **Create Responsive Design**: Bob Smith, as the Designer, has the creative skill set necessary for developing the website's layout and aesthetics, accommodating a 14-day timeframe to ensure thorough iterations.
#
# 3. **Develop User Interface**: Jane Doe, a Software Engineer, is best suited to handle the implementation of the user interface, ensuring adherence to functionality and design specifications.
#
# 4. **Create Navigation System**: Jane Doe takes this task as well, leveraging her UI experience from the previous task to maintain cohesion in user experience design.
#
# 5. **Develop "About Us" Page**: Collaboratively assigned to Jane Doe and Bob Smith, both will ensure the visual and technical aspects of the page align with the overall website theme.
#
# 6. **Design "Services" Page**: Bob Smith is allocated for the service design, allowing for a seamless transition from previous design tasks.
#
# 7. **Create "Contact Us" Page**: This task goes back to Jane Doe to maintain consistency and make use of the insights gained from earlier UI development tasks.
#
# 8. **Implement Blog Section**: Jane Doe pairs up with Bob Smith; the collaborative effort ensures that both the backend setup and frontend design are coherent and functional.
#
# 9. **Website Optimization for SEO**: Again, Jane Doe is assigned to ensure integration of technical SEO practices into the existing development framework.
#
# 10. **Integrate Social Media Links**: Given her familiarity with the website's backend, Jane is apt to do this alone, keeping the timeline in check.
#
# 11. **Design Testimonials Section**: Bob Smith’s design skills will help create an appealing section that aligns with the overall aesthetic of the website.
#
# 12. **Quality Assurance Testing**: Alice Johnson and Tom Brown, as the QA Engineers, will equally divide effort to thoroughly test the features developed and identify critical issues.
#
# 13. **Launch Website**: The project needs a decisive final step managed by John Doe alongside Jane Doe, ensuring that any last-minute issues are addressed promptly before going live.
#
# This allocation maximizes the efficiency and strengths of each team member while managing their workloads without causing burnout, ensuring a successful project completion.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0028
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         18919          11558               7361                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Define Project Requirements',
#    'estimated_time_hours': 6.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 14.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User Interface',
#    'estimated_time_hours': 14.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create Navigation System',
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Develop 'About Us' Page",
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': "Design 'Services' Page",
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 14.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Website Optimization for SEO',
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Design Testimonials Section',
#    'estimated_time_hours': 7.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 13.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 4.0,
#    'required_resources': ['John Doe', 'Jane Doe']}],
#  'milestones': [{'milestone_name': 'Project Requirements Defined',
#    'tasks': ['1']},
#   {'milestone_name': 'Design Complete',
#    'tasks': ['2', '3', '4', '5', '6', '7', '11']},
#   {'milestone_name': 'Development Complete',
#    'tasks': ['3', '4', '5', '6', '8', '9', '10']},
#   {'milestone_name': 'Testing Complete', 'tasks': ['12']},
#   {'milestone_name': 'Website Launched', 'tasks': ['13']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_43d73 th {
#   font-size: 120%;
# }
# #T_43d73  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_43d73" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43d73_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_43d73_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_43d73_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43d73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43d73_row0_col0" class="data row0 col0" >Define Project Requirements</td>
#       <td id="T_43d73_row0_col1" class="data row0 col1" >6.000000</td>
#       <td id="T_43d73_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43d73_row1_col0" class="data row1 col0" >Create Responsive Design</td>
#       <td id="T_43d73_row1_col1" class="data row1 col1" >14.000000</td>
#       <td id="T_43d73_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43d73_row2_col0" class="data row2 col0" >Develop User Interface</td>
#       <td id="T_43d73_row2_col1" class="data row2 col1" >14.000000</td>
#       <td id="T_43d73_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43d73_row3_col0" class="data row3 col0" >Create Navigation System</td>
#       <td id="T_43d73_row3_col1" class="data row3 col1" >7.000000</td>
#       <td id="T_43d73_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43d73_row4_col0" class="data row4 col0" >Develop 'About Us' Page</td>
#       <td id="T_43d73_row4_col1" class="data row4 col1" >7.000000</td>
#       <td id="T_43d73_row4_col2" class="data row4 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43d73_row5_col0" class="data row5 col0" >Design 'Services' Page</td>
#       <td id="T_43d73_row5_col1" class="data row5 col1" >7.000000</td>
#       <td id="T_43d73_row5_col2" class="data row5 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43d73_row6_col0" class="data row6 col0" >Create 'Contact Us' Page</td>
#       <td id="T_43d73_row6_col1" class="data row6 col1" >7.000000</td>
#       <td id="T_43d73_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43d73_row7_col0" class="data row7 col0" >Implement Blog Section</td>
#       <td id="T_43d73_row7_col1" class="data row7 col1" >14.000000</td>
#       <td id="T_43d73_row7_col2" class="data row7 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43d73_row8_col0" class="data row8 col0" >Website Optimization for SEO</td>
#       <td id="T_43d73_row8_col1" class="data row8 col1" >7.000000</td>
#       <td id="T_43d73_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43d73_row9_col0" class="data row9 col0" >Integrate Social Media Links</td>
#       <td id="T_43d73_row9_col1" class="data row9 col1" >7.000000</td>
#       <td id="T_43d73_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_43d73_row10_col0" class="data row10 col0" >Design Testimonials Section</td>
#       <td id="T_43d73_row10_col1" class="data row10 col1" >7.000000</td>
#       <td id="T_43d73_row10_col2" class="data row10 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_43d73_row11_col0" class="data row11 col0" >Quality Assurance Testing</td>
#       <td id="T_43d73_row11_col1" class="data row11 col1" >13.000000</td>
#       <td id="T_43d73_row11_col2" class="data row11 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_43d73_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_43d73_row12_col0" class="data row12 col0" >Launch Website</td>
#       <td id="T_43d73_row12_col1" class="data row12 col1" >4.000000</td>
#       <td id="T_43d73_row12_col2" class="data row12 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_f41d0 th {
#   font-size: 120%;
# }
# #T_f41d0  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_f41d0" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f41d0_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_f41d0_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f41d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f41d0_row0_col0" class="data row0 col0" >Project Requirements Defined</td>
#       <td id="T_f41d0_row0_col1" class="data row0 col1" >['1']</td>
#     </tr>
#     <tr>
#       <th id="T_f41d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f41d0_row1_col0" class="data row1 col0" >Design Complete</td>
#       <td id="T_f41d0_row1_col1" class="data row1 col1" >['2', '3', '4', '5', '6', '7', '11']</td>
#     </tr>
#     <tr>
#       <th id="T_f41d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f41d0_row2_col0" class="data row2 col0" >Development Complete</td>
#       <td id="T_f41d0_row2_col1" class="data row2 col1" >['3', '4', '5', '6', '8', '9', '10']</td>
#     </tr>
#     <tr>
#       <th id="T_f41d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f41d0_row3_col0" class="data row3 col0" >Testing Complete</td>
#       <td id="T_f41d0_row3_col1" class="data row3 col1" >['12']</td>
#     </tr>
#     <tr>
#       <th id="T_f41d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f41d0_row4_col0" class="data row4 col0" >Website Launched</td>
#       <td id="T_f41d0_row4_col1" class="data row4 col1" >['13']</td>
#     </tr>
#   </tbody>
# </table>
